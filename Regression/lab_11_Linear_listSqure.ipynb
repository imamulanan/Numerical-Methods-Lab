# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])


A = np.vstack([x, np.ones(len(x))]).T
m, c = np.linalg.lstsq(A, y, rcond=None)[0]


y_pred = m * x + c


plt.scatter(x, y, color="blue", label="Data Points")
plt.plot(x, y_pred, color="red", label=f"Best fit line: y={m:.2f}x+{c:.2f}")
plt.xlabel("Hours studied (x)")
plt.ylabel("Marks (y)")
plt.title("Linear Least Squares Regression")
plt.legend()
plt.show()


x_new = 6
y_new = m * x_new + c
print(f"Predicted marks for {x_new} hours of study: {y_new:.2f}")
# Out:
# Predicted marks for 6 hours of study: 5.80
